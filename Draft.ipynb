# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Homicides Are Falling Around the World - Homicides Are Falling Around the World.csv")
df
# Out:
#      Unnamed: 0 Intentional homicides (per 100,000 people)  Unnamed: 2  \
# 0       country           % change earliest to latest data     1995.00
# 1       Croatia                                      -0.75        3.56
# 2      Bulgaria                                      -0.70        5.91
# 3   Netherlands                                      -0.69        1.94
# 4    Kazakhstan                                      -0.69       15.36
# ..          ...                                        ...         ...
# 56        Nepal                                      -0.09         NaN
# 57       Canada                                      -0.07        1.84
# 58    Guatemala                                      -0.04       32.55
# 59     Portugal                                      -0.04         NaN
# 60       Mexico                                      -0.04       16.92
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header
df
# Out:
# 0           country % change earliest to latest data  1995.0  1996.0  1997.0  \
# 1           Croatia                            -0.75    3.56    2.62    2.55
# 2          Bulgaria                            -0.70    5.91    5.29    4.85
# 3       Netherlands                            -0.69    1.94    1.36    1.33
# 4        Kazakhstan                            -0.69   15.36   16.71   16.67
# 5            Poland                            -0.68    2.22    2.27    2.10
# 6           Albania                            -0.66    6.69    7.97   49.87
# 7             China                            -0.65     NaN     NaN     NaN
# 8           Georgia                            -0.65    7.71    5.41    5.79
# 9           Moldova                            -0.65    9.10    9.29    9.32
# 10  Slovak Republic                            -0.62    2.38    2.45    2.60
# 11         Colombia                            -0.62   69.67   71.79   67.18
# ...

# %%
test = df.drop(columns=["source", "URL"])
test
# Out:
# 0           country % change earliest to latest data  1995.0  1996.0  1997.0  \
# 1           Croatia                            -0.75    3.56    2.62    2.55
# 2          Bulgaria                            -0.70    5.91    5.29    4.85
# 3       Netherlands                            -0.69    1.94    1.36    1.33
# 4        Kazakhstan                            -0.69   15.36   16.71   16.67
# 5            Poland                            -0.68    2.22    2.27    2.10
# 6           Albania                            -0.66    6.69    7.97   49.87
# 7             China                            -0.65     NaN     NaN     NaN
# 8           Georgia                            -0.65    7.71    5.41    5.79
# 9           Moldova                            -0.65    9.10    9.29    9.32
# 10  Slovak Republic                            -0.62    2.38    2.45    2.60
# 11         Colombia                            -0.62   69.67   71.79   67.18
# ...

# %%
test2 = test.dropna()
test2 = test2.reset_index()
test2 = test2.drop(columns=["index"])
test2
# Out:
# 0           country % change earliest to latest data  1995.0  1996.0  1997.0  \
# 0           Croatia                            -0.75    3.56    2.62    2.55
# 1       Netherlands                            -0.69    1.94    1.36    1.33
# 2        Kazakhstan                            -0.69   15.36   16.71   16.67
# 3            Poland                            -0.68    2.22    2.27    2.10
# 4   Slovak Republic                            -0.62    2.38    2.45    2.60
# 5          Colombia                            -0.62   69.67   71.79   67.18
# 6    Czech Republic                            -0.59    1.71    1.68    1.82
# 7   Kyrgyz Republic                            -0.56   11.65   11.14    9.26
# 8           Romania                            -0.55    3.34    3.20    3.08
# 9             Italy                            -0.55    1.78    1.67    1.53
# 10         Thailand                            -0.54    7.61    7.42    7.86
# ...

# %%
percenthomicides = [test2.loc[test2["country"] == "Poland"]["% change earliest to latest data"].iloc[0], test2.loc[test2["country"] == "Kazakhstan"]["% change earliest to latest data"].iloc[0],
       test2.loc[test2["country"] == "Colombia"]["% change earliest to latest data"].iloc[0], test2.loc[test2["country"] == "Croatia"]["% change earliest to latest data"].iloc[0]]
percenthomicides
# Out:
# ['-0.68', '-0.69', '-0.62', '-0.75']

# %%
listarray = list(np.arange(1995,2016))

# %%
plt.figure(figsize=(10,10))
for i in range(len(test2["country"])):
    plt.plot(listarray,test2.iloc[i,2:23])
plt.xticks(listarray,rotation=90)
plt.xlabel("Years")
plt.ylabel("Intentional homicides (per 100,000 people)")
plt.legend(test2['country'],loc='best', fontsize = 'xx-small')
plt.show()

# %% [markdown]
# Other ideas: map of all countries - size of their dot based on decrease

# %%
df2 = pd.read_csv("freedom-scores.csv")
df2
# Out:
#        Id         Name   Short Name ISO Code  Index Year  Overall Score  \
# 0       1  Afghanistan  Afghanistan       AF        2023            NaN
# 1       2      Albania      Albania       AL        2023           65.3
# 2       3      Algeria      Algeria       DZ        2023           43.2
# 3       4       Angola       Angola       AO        2023           53.0
# 4       5    Argentina    Argentina       AR        2023           51.0
# ...   ...          ...          ...      ...         ...            ...
# 5334  179   Venezuela     Venezuela       VE        1995           59.8
# 5335  180      Vietnam      Vietnam       VN        1995           41.7
# 5336  181        Yemen        Yemen       YE        1995           49.8
# 5337  182       Zambia       Zambia       ZM        1995           55.1
# 5338  183     Zimbabwe     Zimbabwe       ZW        1995           48.5
#
#       Property Rights  Judicial Effectiveness  Government Integrity  \
# ...

# %%
df3 = df2.dropna()
df3 = df3.reset_index()
df3 = df3.drop(columns=["index"])
df3
# Out:
#        Id               Name Short Name ISO Code  Index Year  Overall Score  \
# 0       2            Albania    Albania       AL        2023           65.3
# 1       3            Algeria    Algeria       DZ        2023           43.2
# 2       4             Angola     Angola       AO        2023           53.0
# 3       5          Argentina  Argentina       AR        2023           51.0
# 4       6            Armenia    Armenia       AM        2023           65.1
# ...   ...                ...        ...      ...         ...            ...
# 1239  180            Vietnam    Vietnam       VN        2017           52.4
# 1240  182             Zambia     Zambia       ZM        2017           55.8
# 1241  183           Zimbabwe   Zimbabwe       ZW        2017           44.0
# 1242  185             Kosovo     Kosovo       XK        2017           67.9
# 1243  186  Brunei Darussalam     Brunei       BN        2017           69.8
#
# ...

# %%
temp = df2.loc[(df2["Name"] == "Croatia") | (df2["Name"] == "Colombia") | (df2["Name"] == "Kazakhstan") | (df2["Name"] == "Poland") | (df2["Name"] == "Slovak Republic")]
temp = temp.loc[(temp["Index Year"] >= 1995)  & (temp["Index Year"] <= 2015)]
temp
# Out:
#        Id        Name  Short Name ISO Code  Index Year  Overall Score  \
# 1520   35    Colombia    Colombia       CO        2015           71.7
# 1526   41     Croatia     Croatia       HR        2015           61.5
# 1569   84  Kazakhstan  Kazakhstan       KZ        2015           63.3
# 1617  132      Poland      Poland       PL        2015           68.6
# 1706   35    Colombia    Colombia       CO        2014           70.7
# ...   ...         ...         ...      ...         ...            ...
# 5104  132      Poland      Poland       PL        1996           57.8
# 5190   35    Colombia    Colombia       CO        1995           64.5
# 5196   41     Croatia     Croatia       HR        1995            NaN
# 5239   84  Kazakhstan  Kazakhstan       KZ        1995            NaN
# 5287  132      Poland      Poland       PL        1995           50.7
#
#       Property Rights  Judicial Effectiveness  Government Integrity  \
# ...

# %%
temp2 = temp.groupby(["Name", "Index Year"])
temp2.first()
# Out:
#                       Id Short Name ISO Code  Overall Score  Property Rights  \
# Name     Index Year
# Colombia 1995         35   Colombia       CO           64.5             50.0
#          1996         35   Colombia       CO           64.3             50.0
#          1997         35   Colombia       CO           66.4             50.0
#          1998         35   Colombia       CO           65.5             50.0
#          1999         35   Colombia       CO           65.3             50.0
# ...                  ...        ...      ...            ...              ...
# Poland   2011        132     Poland       PL           64.1             60.0
#          2012        132     Poland       PL           64.2             60.0
#          2013        132     Poland       PL           66.0             60.0
#          2014        132     Poland       PL           67.0             60.0
#          2015        132     Poland       PL           68.6             60.0
#
# ...

# %%
Croatia = temp.loc[temp["Name"] == "Croatia"]
Croatia = Croatia.sort_values("Index Year")
Croatia
# Out:
#       Id     Name Short Name ISO Code  Index Year  Overall Score  \
# 5196  41  Croatia    Croatia       HR        1995            NaN
# 5013  41  Croatia    Croatia       HR        1996      48.000000
# 4830  41  Croatia    Croatia       HR        1997      46.700000
# 4647  41  Croatia    Croatia       HR        1998      51.700000
# 4464  41  Croatia    Croatia       HR        1999      53.100000
# 4281  41  Croatia    Croatia       HR        2000      53.600000
# 4098  41  Croatia    Croatia       HR        2001      50.700000
# 3915  41  Croatia    Croatia       HR        2002      51.100000
# 3732  41  Croatia    Croatia       HR        2003      53.300000
# 3549  41  Croatia    Croatia       HR        2004      53.100000
# 3366  41  Croatia    Croatia       HR        2005      51.900000
# 3183  41  Croatia    Croatia       HR        2006      53.600000
# 3000  41  Croatia    Croatia       HR        2007      53.400000
# ...

# %%
Colombia = temp.loc[temp["Name"] == "Colombia"]
Colombia = Colombia.sort_values("Index Year")
Colombia
# Out:
#       Id      Name Short Name ISO Code  Index Year  Overall Score  \
# 5190  35  Colombia   Colombia       CO        1995      64.500000
# 5007  35  Colombia   Colombia       CO        1996      64.300000
# 4824  35  Colombia   Colombia       CO        1997      66.400000
# 4641  35  Colombia   Colombia       CO        1998      65.500000
# 4458  35  Colombia   Colombia       CO        1999      65.300000
# 4275  35  Colombia   Colombia       CO        2000      63.300000
# 4092  35  Colombia   Colombia       CO        2001      65.600000
# 3909  35  Colombia   Colombia       CO        2002      64.200000
# 3726  35  Colombia   Colombia       CO        2003      64.200000
# 3543  35  Colombia   Colombia       CO        2004      61.200000
# 3360  35  Colombia   Colombia       CO        2005      59.600000
# 3177  35  Colombia   Colombia       CO        2006      60.400000
# 2994  35  Colombia   Colombia       CO        2007      59.900000
# ...

# %%
Kazakhstan = temp.loc[temp["Name"] == "Kazakhstan"]
Kazakhstan = Kazakhstan.sort_values("Index Year")
Kazakhstan
# Out:
#       Id        Name  Short Name ISO Code  Index Year  Overall Score  \
# 5239  84  Kazakhstan  Kazakhstan       KZ        1995            NaN
# 5056  84  Kazakhstan  Kazakhstan       KZ        1996            NaN
# 4873  84  Kazakhstan  Kazakhstan       KZ        1997            NaN
# 4690  84  Kazakhstan  Kazakhstan       KZ        1998      41.700000
# 4507  84  Kazakhstan  Kazakhstan       KZ        1999      47.300000
# 4324  84  Kazakhstan  Kazakhstan       KZ        2000      50.400000
# 4141  84  Kazakhstan  Kazakhstan       KZ        2001      51.800000
# 3958  84  Kazakhstan  Kazakhstan       KZ        2002      52.400000
# 3775  84  Kazakhstan  Kazakhstan       KZ        2003      52.300000
# 3592  84  Kazakhstan  Kazakhstan       KZ        2004      49.700000
# 3409  84  Kazakhstan  Kazakhstan       KZ        2005      53.900000
# 3226  84  Kazakhstan  Kazakhstan       KZ        2006      60.200000
# 3043  84  Kazakhstan  Kazakhstan       KZ        2007      59.600000
# ...

# %%
Poland = temp.loc[temp["Name"] == "Poland"]
Poland = Poland.sort_values("Index Year")
Poland
# Out:
#        Id    Name Short Name ISO Code  Index Year  Overall Score  \
# 5287  132  Poland     Poland       PL        1995      50.700000
# 5104  132  Poland     Poland       PL        1996      57.800000
# 4921  132  Poland     Poland       PL        1997      56.800000
# 4738  132  Poland     Poland       PL        1998      59.200000
# 4555  132  Poland     Poland       PL        1999      59.600000
# 4372  132  Poland     Poland       PL        2000      60.000000
# 4189  132  Poland     Poland       PL        2001      61.800000
# 4006  132  Poland     Poland       PL        2002      65.000000
# 3823  132  Poland     Poland       PL        2003      61.800000
# 3640  132  Poland     Poland       PL        2004      58.700000
# 3457  132  Poland     Poland       PL        2005      59.600000
# 3274  132  Poland     Poland       PL        2006      59.300000
# 3091  132  Poland     Poland       PL        2007      58.100000
# ...

# %%
countryarray = ["Poland", "Kazakhstan", "Colombia", "Croatia"]

# %%
plt.plot(Poland["Index Year"],Poland["Overall Score"])
plt.plot(Kazakhstan["Index Year"],Kazakhstan["Overall Score"])
plt.plot(Colombia["Index Year"],Colombia["Overall Score"])
plt.plot(Croatia["Index Year"],Croatia["Overall Score"])
plt.xticks(Croatia["Index Year"],rotation=90)
plt.xlabel("Years")
plt.ylabel("Overall Score")
plt.legend(countryarray,loc='best', fontsize = 'xx-small')
plt.show()

# %%
polandpercent = (Poland.loc[Poland["Index Year"] == 2015]["Overall Score"].reset_index(drop=True) - Poland.loc[Poland["Index Year"] == 1995]["Overall Score"].reset_index(drop=True)) / Poland.loc[Poland["Index Year"] == 2015]["Overall Score"].reset_index(drop=True)
polandpercent = polandpercent * 100
kazakhstanpercent = (Kazakhstan.loc[Kazakhstan["Index Year"] == 2015]["Overall Score"].reset_index(drop=True) - Kazakhstan.loc[Kazakhstan["Index Year"] == 1998]["Overall Score"].reset_index(drop=True)) / Kazakhstan.loc[Kazakhstan["Index Year"] == 2015]["Overall Score"].reset_index(drop=True)
kazakhstanpercent = kazakhstanpercent * 100
colombiapercent = (Colombia.loc[Colombia["Index Year"] == 2015]["Overall Score"].reset_index(drop=True) - Colombia.loc[Colombia["Index Year"] == 1995]["Overall Score"].reset_index(drop=True)) / Colombia.loc[Colombia["Index Year"] == 2015]["Overall Score"].reset_index(drop=True)
colombiapercent = colombiapercent * 100
croatiapercent = (Croatia.loc[Croatia["Index Year"] == 2015]["Overall Score"].reset_index(drop=True) - Croatia.loc[Croatia["Index Year"] == 1996]["Overall Score"].reset_index(drop=True)) / Croatia.loc[Croatia["Index Year"] == 2015]["Overall Score"].reset_index(drop=True)
croatiapercent = croatiapercent * 100

# %%
kazakhstanpercent
# Out:
# 0    34.123223
# Name: Overall Score, dtype: float64

# %%
changefreedomscore = [polandpercent.iloc[0], kazakhstanpercent.iloc[0], colombiapercent.iloc[0], croatiapercent.iloc[0]]
changefreedomscore
# Out:
# [26.093294460641392, 34.12322274881516, 10.041841004184104, 21.951219512195124]

# %%
combinded_df = pd.DataFrame({
    "Country Name" : countryarray,
    "% Change in Homicides: 1995 - 2015" : percenthomicides,
    '% Change in Overall Freedome Score: Earliest Data - 2015' : changefreedomscore
})
combinded_df
# Out:
#   Country Name % Change in Homicides: 1995 - 2015  \
# 0       Poland                              -0.68
# 1   Kazakhstan                              -0.69
# 2     Colombia                              -0.62
# 3      Croatia                              -0.75
#
#    % Change in Overall Freedome Score: Earliest Data - 2015
# 0                                          26.093294
# 1                                          34.123223
# 2                                          10.041841
# 3                                          21.951220
